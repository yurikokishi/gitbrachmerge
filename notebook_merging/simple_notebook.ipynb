# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# let's put more markdown here.

# %%
x = np.linspace(0,10)
y = np.sin(x)

# %%
plt.plot(y, y)

# %%
plt.plot(y, x)

# %% [markdown]
# Let's add some Markdown.
